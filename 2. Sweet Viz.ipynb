# %% [markdown]
# sweetviz is a great tool to quickly get a view of your dataset.

# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
#read in data 
df = pd.read_csv("data/flight_and_dimension.csv", sep='\t',encoding='utf-8')
df.head()
# Out:
#        Brand             Mold      Type  Speed  Glide  Turn  Fade In Prod.  \
# 0  ABC Discs         Bee Line  Distance   14.0    5.0  -3.0   2.0      Yes
# 1  ABC Discs  Flying Squirrel  Midrange    6.0    5.0  -3.0   2.0      Yes
# 2  ABC Discs          Mission  Midrange    4.0    5.0  -1.0   2.0      Yes
# 3  ABC Discs            Money    Putter    2.0    3.0   0.0   2.0      Yes
# 4  ABC Discs    Secret Weapon  Distance   10.0    5.0  -3.0   2.0      Yes
#
#   Date Approved  Max Weight (gr)  Diameter (cm)  Height (cm)  Rim Depth (cm)  \
# 0    2012-09-12            175.1           21.1          1.6             1.1
# 1    2010-05-29            181.8           21.9          2.0             1.4
# 2    2010-07-27            180.9           21.8          2.0             1.4
# 3    2010-04-09            174.3           21.0          2.2             1.7
# 4    2010-05-29            175.1           21.1          2.0             1.1
#
#    Inside Rim Diameter (cm)  Rim Thickness (cm)  \
# ...

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Brand                           669 non-null    object
#  1   Mold                            669 non-null    object
#  2   Type                            669 non-null    object
#  3   Speed                           669 non-null    float64
#  4   Glide                           669 non-null    float64
#  5   Turn                            669 non-null    float64
#  6   Fade                            669 non-null    float64
#  7   In Prod.                        669 non-null    object
#  8   Date Approved                   669 non-null    object
#  9   Max Weight (gr)                 669 non-null    float64
#  10  Diameter (cm)                   669 non-null    float64
#  11  Height (cm)                     669 non-null    float64
# ...

# %% [markdown]
# ## Fixing Type Column
# There are some discs that have spaces after their disc type

# %%
df['Type'].unique()
# Out:
# array(['Distance', 'Midrange', 'Putter', 'Fairway', 'Fairway ',
#        'Distance '], dtype=object)

# %%
#fixing the types with spaces at the end
df['Type'] = df['Type'].str.strip()
df['Type'].unique()
# Out:
# array(['Distance', 'Midrange', 'Putter', 'Fairway'], dtype=object)

# %% [markdown]
# ## Droping Unneeded Columns
# drop In Prod., Date Approved, Certification Number

# %%
df = df.drop(['In Prod.','Date Approved','Certification Number'],axis=1)

# %%
df.head()
# Out:
#        Brand             Mold      Type  Speed  Glide  Turn  Fade  \
# 0  ABC Discs         Bee Line  Distance   14.0    5.0  -3.0   2.0
# 1  ABC Discs  Flying Squirrel  Midrange    6.0    5.0  -3.0   2.0
# 2  ABC Discs          Mission  Midrange    4.0    5.0  -1.0   2.0
# 3  ABC Discs            Money    Putter    2.0    3.0   0.0   2.0
# 4  ABC Discs    Secret Weapon  Distance   10.0    5.0  -3.0   2.0
#
#    Max Weight (gr)  Diameter (cm)  Height (cm)  Rim Depth (cm)  \
# 0            175.1           21.1          1.6             1.1
# 1            181.8           21.9          2.0             1.4
# 2            180.9           21.8          2.0             1.4
# 3            174.3           21.0          2.2             1.7
# 4            175.1           21.1          2.0             1.1
#
#    Inside Rim Diameter (cm)  Rim Thickness (cm)  \
# 0                      16.2                 2.5
# 1                      19.4                 1.3
# ...

# %%
my_report = sv.analyze(df)
my_report.show_html()
# Out:
# ...
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.describe()
# Out:
#             Speed       Glide        Turn        Fade  Max Weight (gr)  \
# count  669.000000  669.000000  669.000000  669.000000       669.000000
# mean     7.260837    4.266816   -0.879671    2.010912       176.516741
# std      3.893749    1.096144    1.128074    1.135182         2.241395
# min      1.000000    1.000000   -5.000000    0.000000       174.300000
# 25%      4.000000    4.000000   -1.500000    1.000000       175.100000
# 50%      7.000000    4.000000   -0.500000    2.000000       176.000000
# 75%     11.000000    5.000000    0.000000    3.000000       176.800000
# max     15.000000    7.000000    1.000000    5.000000       196.700000
#
#        Diameter (cm)  Height (cm)  Rim Depth (cm)  Inside Rim Diameter (cm)  \
# count     669.000000   669.000000      669.000000                669.000000
# mean       21.266816     1.807922        1.257549                 17.922422
# std         0.269629     0.242208        0.163670                  1.138759
# ...

# %%
df[df['Rim Configuration']<30]
# Out:
#                   Brand           Mold      Type  Speed  Glide  Turn  Fade  \
# 0             ABC Discs       Bee Line  Distance   14.0    5.0  -3.0   2.0
# 4             ABC Discs  Secret Weapon  Distance   10.0    5.0  -3.0   2.0
# 5    Above Ground Level        Cypress  Distance   12.0    5.0  -2.0   2.0
# 8               Aerobie    Epic Driver  Distance   11.0    3.0  -2.0   4.0
# 10     AquaFlight Discs         Osprey  Distance   12.0    4.0  -1.0   2.0
# ..                  ...            ...       ...    ...    ...   ...   ...
# 646          Streamline           Lift   Fairway    9.0    5.0  -2.0   1.5
# 653      Infinite Discs        Scepter   Fairway    9.0    3.0   0.0   4.0
# 654           Discmania         Enigma  Distance   13.0    5.0  -1.0   3.0
# 656         Axiom Discs       Delirium  Distance   14.5    5.0  -0.5   3.0
# 661            Discraft           Anax   Fairway   10.0    6.0   0.0   3.0
#
#      Max Weight (gr)  Diameter (cm)  Height (cm)  Rim Depth (cm)  \
# ...
